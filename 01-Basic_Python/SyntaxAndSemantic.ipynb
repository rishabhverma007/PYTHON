# %% [markdown]
# # ## Syntax and Semantics in Python
# ## Video Outline:
# 1. Single line comments and multiline comments
# 2. Defination of syntax and semantics
# 3. Basic Syntax rules in python
# 4. Understanding Semantics in python
# 5. Common Syntax Errors and how to avoid them
# 6. Practical code examples

# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctky structured porgrams in a language. In simpler terms, syntax is about the sorrect arrangement of words and symbols in a code.

# %% [markdown]
# Semantic refers to the meaning or the interpretation of the symbols, charecters, and commands in a language. It is about what the code is supposed to do when it runs.

# %%
## Basic Syntax Rules in Python
## Case Sensitivity : Python is case sensitive
name = "Rishabh"
Name = "Rishabh"
print(name)
print(Name)
# Out:
# Rishabh
# Rishabh

# %% [markdown]
# ##INDENTATION
#
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## INDENTATION
## Python uses indentation to define blocks of code. Proper indentation is crucial for the correct execution of the program.

age = 18
if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult

# %%
## THIS IS SINGLE LINE COMMENT
## THIS IS MULTILINE COMMENT

"""HEY MY NAME IS RISHABH VERMA."""
# Out:
# 'HEY MY NAME IS RISHABH VERMA.'

# %%
## Multiple Statements on a single line
a=5; b=10; c=15;d=a+b+c;
print(d)
# Out:
# 30

# %%
## Variable Assignments
name = "Rishabh"
roll_number = 41
print(type(name))
print(type(roll_number))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Code example of Identation

if True:
    print("Correct Indentaion")
    if False:
        print("Incorrect Indentation")
    print("This will print")
print("This is out of the if block")
